# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report

# Define dataset path
data_dir = "Emotional_Detection_NullClass"  # Update with actual dataset path

# Image Data Generator for preprocessing
datagen = ImageDataGenerator(rescale=1./255, validation_split=0.2)

train_generator = datagen.flow_from_directory(
    data_dir,
    target_size=(48, 48),
    batch_size=32,
    class_mode='categorical',
    subset='training'
)

val_generator = datagen.flow_from_directory(
    data_dir,
    target_size=(48, 48),
    batch_size=32,
    class_mode='categorical',
    subset='validation'
)

# Build CNN model
model = Sequential([
    Conv2D(32, (3,3), activation='relu', input_shape=(48,48,3), name="conv2d_1"),
    MaxPooling2D(2,2, name="max_pooling2d_1"),
    
    Conv2D(64, (3,3), activation='relu', name="conv2d_2"),
    MaxPooling2D(2,2, name="max_pooling2d_2"),
    
    Conv2D(128, (3,3), activation='relu', name="conv2d_3"),
    MaxPooling2D(2,2, name="max_pooling2d_3"),
    
    Flatten(name="flatten"),
    Dense(128, activation='relu', name="dense_1"),
    Dropout(0.5, name="dropout"),
    Dense(train_generator.num_classes, activation='softmax', name="output")
])

# Compile model
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# Train model
history = model.fit(train_generator, validation_data=val_generator, epochs=25)

# Save model and weights
model.save("emotion_model.h5")

# Evaluate model
y_true = []
y_pred = []

for images, labels in val_generator:
    preds = model.predict(images)
    y_pred.extend(np.argmax(preds, axis=1))
    y_true.extend(np.argmax(labels, axis=1))
    if len(y_true) >= val_generator.samples:
        break

# Confusion Matrix
cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(8,6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

# Classification Report
print(classification_report(y_true, y_pred))
# Out:
# Found 14052 images belonging to 3 classes.
# Found 3512 images belonging to 3 classes.
# C:\Users\Mihir\anaconda3\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# C:\Users\Mihir\anaconda3\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/25
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 74s 147ms/step - accuracy: 0.5880 - loss: 0.7005 - val_accuracy: 0.6054 - val_loss: 0.6720
# Epoch 2/25
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 55s 125ms/step - accuracy: 0.6045 - loss: 0.6741 - val_accuracy: 0.6054 - val_loss: 0.6777
# Epoch 3/25
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 53s 121ms/step - accuracy: 0.6009 - loss: 0.6761 - val_accuracy: 0.6054 - val_loss: 0.6712
# Epoch 4/25
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 38s 85ms/step - accuracy: 0.6003 - loss: 0.6739 - val_accuracy: 0.6054 - val_loss: 0.6712
# Epoch 5/25
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 38s 79ms/step - accuracy: 0.6047 - loss: 0.6727 - val_accuracy: 0.6054 - val_loss: 0.6709
# Epoch 6/25
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 34s 77ms/step - accuracy: 0.6067 - loss: 0.6720 - val_accuracy: 0.6054 - val_loss: 0.6723
# Epoch 7/25
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 35s 80ms/step - accuracy: 0.6076 - loss: 0.6707 - val_accuracy: 0.6054 - val_loss: 0.6714
# Epoch 8/25
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 36s 82ms/step - accuracy: 0.5994 - loss: 0.6740 - val_accuracy: 0.6054 - val_loss: 0.6713
# Epoch 9/25
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 36s 82ms/step - accuracy: 0.6104 - loss: 0.6697 - val_accuracy: 0.6054 - val_loss: 0.6708
# Epoch 10/25
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 38s 87ms/step - accuracy: 0.6109 - loss: 0.6696 - val_accuracy: 0.6054 - val_loss: 0.6708
# Epoch 11/25
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 34s 77ms/step - accuracy: 0.6028 - loss: 0.6724 - val_accuracy: 0.6054 - val_loss: 0.6710
# Epoch 12/25
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 34s 77ms/step - accuracy: 0.6034 - loss: 0.6725 - val_accuracy: 0.6054 - val_loss: 0.6708
# Epoch 13/25
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 48s 109ms/step - accuracy: 0.6031 - loss: 0.6722 - val_accuracy: 0.6054 - val_loss: 0.6710
# Epoch 14/25
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 49s 112ms/step - accuracy: 0.6146 - loss: 0.6676 - val_accuracy: 0.6054 - val_loss: 0.6710
# Epoch 15/25
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 34s 78ms/step - accuracy: 0.6031 - loss: 0.6724 - val_accuracy: 0.6054 - val_loss: 0.6709
# Epoch 16/25
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 34s 77ms/step - accuracy: 0.6049 - loss: 0.6716 - val_accuracy: 0.6054 - val_loss: 0.6708
# Epoch 17/25
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 34s 77ms/step - accuracy: 0.6116 - loss: 0.6685 - val_accuracy: 0.6054 - val_loss: 0.6708
# Epoch 18/25
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 34s 77ms/step - accuracy: 0.6057 - loss: 0.6714 - val_accuracy: 0.6054 - val_loss: 0.6716
# Epoch 19/25
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 3215s 7s/step - accuracy: 0.6036 - loss: 0.6722 - val_accuracy: 0.6054 - val_loss: 0.6708
# Epoch 20/25
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 46s 104ms/step - accuracy: 0.5941 - loss: 0.6758 - val_accuracy: 0.6054 - val_loss: 0.6711
# Epoch 21/25
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 51s 116ms/step - accuracy: 0.6063 - loss: 0.6710 - val_accuracy: 0.6054 - val_loss: 0.6708
# Epoch 22/25
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 52s 117ms/step - accuracy: 0.6061 - loss: 0.6703 - val_accuracy: 0.6054 - val_loss: 0.6708
# Epoch 23/25
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 45s 102ms/step - accuracy: 0.5978 - loss: 0.6737 - val_accuracy: 0.6051 - val_loss: 0.6731
# Epoch 24/25
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 33s 76ms/step - accuracy: 0.6011 - loss: 0.6729 - val_accuracy: 0.6042 - val_loss: 0.6731
# Epoch 25/25
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 34s 77ms/step - accuracy: 0.6058 - loss: 0.6707 - val_accuracy: 0.6036 - val_loss: 0.6722
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 385ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 262ms/step
#               precision    recall  f1-score   support
#
#            1       0.35      0.01      0.01      1386
#            2       0.61      0.99      0.75      2126
#
#     accuracy                           0.60      3512
#    macro avg       0.48      0.50      0.38      3512
# weighted avg       0.50      0.60      0.46      3512
